# %%
import pandas as pd
import numpy as np

from fbprophet import Prophet
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
dataset= pd.read_csv("ecount_pred.csv")
dataset.head()
# Out:
#            ds      y
# 0  2019-01-02   3974
# 1  2019-01-03  14070
# 2  2019-01-04   9375
# 3  2019-01-05  10320
# 4  2019-01-06  19649

# %%
model= Prophet()
model.fit(dataset)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\0123456789\Anaconda3\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
future_data= model.make_future_dataframe(periods= 6, freq= 'm')

# %%
forecast_data= model.predict(future_data)

# %%
model.plot(forecast_data)

# %%
model.plot_components(forecast_data)
